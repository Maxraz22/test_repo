# %% [markdown]
# # Завдання

# %% [markdown]
# Реалізуйте функцію для зчитування зображення з файлу та його відображення за допомогою бібліотеки OpenCV. Реалізуйте фільтр Собеля для зображення та відобразіть його результат. Реалізуйте медіанний фільтр для зображення та відобразіть його результат. Порівняйте результати фільтрів Собеля та медіанного фільтру та проілюструйте їх відмінності на зображенні.

# %% [markdown]
# # Розв'язок

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. Функція для зчитування зображення з файлу та його відображення за допомогою бібліотеки OpenCV

# %%
def reading(file):
    image = cv2.imread(file)  
    if image is not None:
        cv2.imshow("Image", image)
        cv2.waitKey(0)
    else:
        print("Не вдалося зчитати зображення з файлу")

# %%
file = "leo.jpg"
reading(file)

# %% [markdown]
# ### 2. Реалізація фільтру Собеля для зображення та відображення його результату

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
kernel_x = np.array([[-1, 0, 1], [-2, 0, 2], [-1, 0, 1]])
kernel_y = np.array([[-1, -2, -1], [0, 0, 0], [1, 0, 1]])

# %%
edges_x = cv2.filter2D(gray, -1, kernel_x)
edges_y = cv2.filter2D(gray, -1, kernel_y)
edges = edges_x + edges_y

# %%
cv2.imshow("Edges", edges)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### 3. Реалізація медіанного фільтру для зображення та відображення його результату

# %%
dst = cv2.medianBlur(img, 7)

cv2.imshow("Median", dst)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### 4. Порівняння результатів

# %%
plt.axis("off")
plt.imshow(edges)
print("Результат реалізації Фільтру Собеля")
plt.show()
# Out:
# Результат реалізації Фільтру Собеля

# %%
plt.axis("off")
plt.imshow(dst)
print("Результат реалізації медіанного фільтру")
plt.show()
# Out:
# Результат реалізації медіанного фільтру

# %% [markdown]
# **Таким чином, за результатами застосування двох різних методів обробки одного і того ж зображення ми пересвідчились у тому, що принципова відмінність між фільтром Собеля і медіанним фільтром полягає у їх функціональності та призначенні. Фільтр Собеля є лінійним фільтром і результатом його застосування є зображення, в якому пікселі, які є частинами країв, мають значення, що відображає величину та напрямок градієнту, тобто виокремлюються контури об'єктів на зображенні. А медіанний фільтр є нелінійним фільтром, який використовується для зменшення шуму на зображенні. Він працює шляхом заміни кожного пікселя на медіану його сусідніх пікселів в зазначеному радіусі.**
