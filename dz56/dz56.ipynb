# %% [markdown]
# # Завдання

# %% [markdown]
# Завантажити зображення cat.jpg, що знаходиться в репозиторії лекції. Проведіть для цього зображення:
#
# + декомпозицію по складових RGB-моделі
# + декомпозицію по складових HSV-моделі
# + декомпозицію по складових моделі CIE LAB

# %% [markdown]
# # Розв'язок

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.colors as clr

# %%
im = cv2.imread('cat.jpg')
im
# Out:
# array([[[144,  85,  83],
#         [147,  91,  86],
#         [148,  93,  84],
#         ...,
#         [ 64,  96, 149],
#         [ 64,  96, 149],
#         [ 64,  96, 149]],
#
#        [[133,  90,  81],
#         [137,  95,  83],
#         [136,  96,  84],
#         ...,
#         [ 66,  98, 151],
#         [ 66,  98, 151],
#         [ 66,  98, 151]],
#
#        [[107,  97,  73],
#         [110,  99,  77],
#         [112,  99,  83],
#         ...,
#         [ 66, 100, 153],
#         [ 66, 100, 153],
#         [ 66, 100, 153]],
#
#        ...,
#
#        [[133, 152, 159],
#         [137, 156, 163],
#         [142, 160, 167],
#         ...,
#         [153, 113,  71],
#         [153, 113,  71],
#         [153, 114,  70]],
#
#        [[130, 149, 156],
#         [135, 154, 161],
#         [141, 159, 166],
#         ...,
#         [154, 114,  72],
#         [154, 114,  72],
#         [153, 114,  70]],
#
#        [[129, 148, 155],
#         [134, 153, 160],
#         [141, 159, 166],
# ...

# %%
im = cv2.imread('cat.jpg')
plt.axis('off')
plt.imshow(im)
plt.show()

# %%
im_RGB = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
plt.axis('off')
plt.imshow(im_RGB)
plt.show()

# %% [markdown]
# ### Декомпозиція по складових RGB-моделі

# %%
R = im_RGB.copy()

# %%
R[:,:,(1,2)] = 0
plt.axis('off')
plt.imshow(R)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
G = im_RGB.copy()
G[:,:,(0,2)] = 0
plt.axis('off')
plt.imshow(G)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
B = im_RGB.copy()
B[:,:,(0,1)] = 0
plt.axis('off')
plt.imshow(B)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Декомпозиція по складових HSV-моделі

# %%
im_HSV = cv2.cvtColor(im, cv2.COLOR_BGR2HSV)

# %%
plt.axis('off')
plt.imshow(im_HSV)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
im_HSV2 = cv2.cvtColor(im_RGB, cv2.COLOR_RGB2HSV)
plt.axis('off')
plt.imshow(im_HSV2)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
im_HSV
# Out:
# array([[[119, 108, 144],
#         [118, 106, 147],
#         [116, 110, 148],
#         ...,
#         [ 11, 145, 149],
#         [ 11, 145, 149],
#         [ 11, 145, 149]],
#
#        [[115, 100, 133],
#         [113, 101, 137],
#         [113,  98, 136],
#         ...,
#         [ 11, 144, 151],
#         [ 11, 144, 151],
#         [ 11, 144, 151]],
#
#        [[ 99,  81, 107],
#         [100,  76, 110],
#         [103,  66, 112],
#         ...,
#         [ 12, 145, 153],
#         [ 12, 145, 153],
#         [ 12, 145, 153]],
#
#        ...,
#
#        [[ 22,  42, 159],
#         [ 22,  41, 163],
#         [ 22,  38, 167],
#         ...,
#         [105, 137, 153],
#         [105, 137, 153],
#         [104, 138, 153]],
#
#        [[ 22,  42, 156],
#         [ 22,  41, 161],
#         [ 22,  38, 166],
#         ...,
#         [105, 136, 154],
#         [105, 136, 154],
#         [104, 138, 153]],
#
#        [[ 22,  43, 155],
#         [ 22,  41, 160],
#         [ 22,  38, 166],
# ...

# %%
H = im_HSV.copy()
H[:, :, (0,1)] = 255
plt.show()
plt.axis('off')
plt.imshow(H)

# %%
S = im_HSV.copy()
S[:,:,(0,2)] = 100
plt.axis('off')
plt.imshow(S)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
V = im_HSV.copy()
V[:,:,(0,1)] = 100
plt.axis('off')
plt.imshow(V)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Декомпозиція по складових моделі CIE LAB

# %%
im_LAB = cv2.cvtColor(im_RGB, cv2.COLOR_BGR2LAB)
plt.axis('off')
plt.imshow(im_LAB)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
L = im_LAB.copy()
L[:,:,(1,2)] = 100
plt.axis('off')
plt.imshow(L)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
A = im_LAB.copy()
A[:,:,(0,2)] = 127
plt.axis('off')
plt.imshow(A)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
B = im_LAB.copy()
B[:,:,(0,1)] = 127
plt.axis('off')
plt.imshow(B)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
im = cv2.cvtColor(im_LAB, cv2.COLOR_LAB2BGR)
plt.axis('off')
plt.imshow(out)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
