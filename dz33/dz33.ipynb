# %% [markdown]
# # Завдання #

# %% [markdown]
# 1. Створіть xls-документ, що містить дані про марки автомобілів, їхню вартість, споживання палива, максимальну швидкість, вантажопідйомність. Кількість записів у документі - 20.
#
# 2. Візуалізуйте залежності: споживання палива від вартості - лінійною діаграмою; споживання палива від швидкості - точковим графіком; вантажопідйомність від швидкості - точковим графіком.
#
# 3. Побудуйте гістограму для розділення автомобілів на 5 груп за швидкістю.
#
# 4. Побудуйте коробковий графік для відображення швидкостей різних марок.
#
# 5. Побудуйте парний графік для відображення залежностей величин.

# %% [markdown]
# # Розв'язок #

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### 1. Створення датафрейму з xls-документу: ####

# %%
df_cars = pd.read_excel('cars.xlsx')
df_cars
# Out:
#                     Car   Cost   Oil  Speed  Load_capacity
# 0       Toyota Corolla   19600   8.7    180            590
# 1            Ford F-150  28155  11.7    210           1100
# 2          Ford Mustang  26670  13.0    250            600
# 3           Honda Civic  21050   8.4    180            550
# 4         Toyota Tacoma  19000   8.0    175            520
# 5       Hyundai Elantra  17100   8.8    200            590
# 6      Chevrolet Camaro  16550  10.0    185            600
# 7            Kia Optima  22140   8.7    180            590
# 8       Honda Ridgeline  20100   8.2    190            580
# 9         Nissan Altima  25120   7.5    210            610
# 10       Subaru Outback  26645  10.0    220            800
# 11         Toyota Camry  27010   9.0    180            720
# 12        Ford Explorer  32785   6.8    190            680
# 13         Honda Accord  28330   7.0    200            510
# 14  Jeep Grand Cherokee  31695  13.0    190           1600
# 15        Nissan Maxima  33920   9.0    185            850
# 16         Kia Sportage  28000   7.0    230            500
# 17      Honda Ridgeline  29990  11.5    210           1520
# 18              Audi A4  37400   8.2    195            720
# 19  Chevrolet Silverado  28300  11.5    210            920

# %% [markdown]
# #### 2. Візуалізація залежності: ####

# %% [markdown]
# ##### Залежність споживання палива від вартості #####

# %%
sns.set_style('darkgrid')
plt.plot(sorted(df_cars['Cost']), sorted(df_cars['Oil']), color = 'blue', linewidth = 3)
plt.xlabel('Вартість авто, $')
plt.ylabel('Споживання палива, мпг')
# Out:
# Text(0, 0.5, 'Споживання палива, мпг')

# %% [markdown]
# ##### Залежність споживання палива від швидкості #####

# %%
plt.scatter(sorted(df_cars['Speed']), sorted(df_cars['Oil']), color = 'blue', marker = 'D')
plt.xlabel('Швидкість, км/год')
plt.ylabel('Споживання палива, мпг')
# Out:
# Text(0, 0.5, 'Споживання палива, мпг')

# %% [markdown]
# ##### Залежність вантажопідйомності від швидкості #####

# %%
plt.scatter(sorted(df_cars['Speed']), sorted(df_cars['Load_capacity']), color = 'blue', marker = '^')
plt.xlabel('Швидкість, км/год')
plt.ylabel('Вантажопідйомність, кг')
# Out:
# Text(0, 0.5, 'Вантажопідйомність, кг')

# %% [markdown]
# #### 3. Побудова гістограми: ####

# %%
plt.hist(df_cars['Speed'], 5, color = 'blue', width = 13.5)
plt.xlabel('Швидкість, км/год')
plt.ylabel('Марки авто, шт.')
# Out:
# Text(0, 0.5, 'Марки авто, шт.')

# %% [markdown]
# #### 4. Побудова коробкового графіку: ####

# %%
sns.boxplot(x='Speed', y='Car', data=df_cars)
# Out:
# <AxesSubplot: xlabel='Speed', ylabel='Car'>

# %% [markdown]
# #### 4. Побудова парного графіку: ####

# %%
sns.pairplot(df_cars)
