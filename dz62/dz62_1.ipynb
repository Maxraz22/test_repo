# %% [markdown]
# # Завдання

# %% [markdown]
# 1. Напишіть код для визначення границь та кутів у зображенні за допомогою фільтра Собеля.
# 2. Використовуючи метод густини градієнта (HOG), напишіть код для витягування ознак з зображення.
# 3. Завантажте датасет COFAR-10 та використайте HOG для отримання ознак зображень. Застосуйте будь-який простий класифікатор (наприклад SVM) для класифікації зображень та обчисліть метрики точності, такі як accuracy, precision, recall та F1-score.

# %% [markdown]
# # Розв'язок

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. Напишіть код для визначення границь та кутів у зображенні за допомогою фільтра Собеля.

# %%
img = cv2.imread('leo.jpg')

# %%
plt.axis('off')
plt.imshow(img)
plt.show()

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.axis('off')
plt.imshow(gray, cmap='gray')
plt.show()

# %%
sobelx = cv2.Sobel(gray, cv2.CV_64F, 2, 0, ksize=5)
sobely = cv2.Sobel(gray, cv2.CV_64F, 0, 2, ksize=5)
mag, ang = cv2.cartToPolar(sobelx, sobely, angleInDegrees=True)

# %% [markdown]
# **Відображення визначених границь**

# %%
plt.axis('off')
plt.imshow(mag, cmap='gray')
plt.show()

# %% [markdown]
# **Відображення визначених кутів**

# %%
plt.axis('off')
plt.imshow(ang, cmap='gray')
plt.show()
