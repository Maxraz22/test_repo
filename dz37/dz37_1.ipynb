# %% [markdown]
# # Завдання

# %% [markdown]
# Використовуючи датасет з файлу Position_Salaries.csv, побудуйте модель поліноміальної регресії.

# %% [markdown]
# # Розв'язок

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
data = pd.read_csv('Position_Salaries.csv')
data
# Out:
#             Position  Level   Salary
# 0   Business Analyst      1    45000
# 1  Junior Consultant      2    50000
# 2  Senior Consultant      3    60000
# 3            Manager      4    80000
# 4    Country Manager      5   110000
# 5     Region Manager      6   150000
# 6            Partner      7   200000
# 7     Senior Partner      8   300000
# 8            C-level      9   500000
# 9                CEO     10  1000000

# %%
x = data.Level
y = data.Salary

# %%
plt.scatter(x,y)
plt.xlabel('Level')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
model = np.poly1d(np.polyfit(x, y, 3))

polyline = np.linspace(1, 10)
plt.scatter(x, y)
plt.xlabel('Level')
plt.ylabel('Salary')
plt.plot(polyline, model(polyline))
plt.show()

# %%
print(model)
# Out:
#       3             2
# 4120 x - 4.855e+04 x + 1.807e+05 x - 1.213e+05

# %%
y_pred = model(x)
rmse = np.sqrt(np.mean(np.square(y-y_pred)))
print(f'RMSE for Polynomial Regression =>: {rmse:.2f}')
# Out:
# RMSE for Polynomial Regression =>: 38931.50

# %% [markdown]
# #### Порівняння із лінійною регресією

# %%
lin_reg = LinearRegression()

# %%
x_l = np.array(x)
y_l = np.array(y)
lin_reg.fit(x_l.reshape(-1,1), y_l.reshape(-1,1))
# Out:
# LinearRegression()

# %%
y_pred1 = lin_reg.predict(x_l.reshape(-1,1))
                    
plt.figure(figsize=(6, 5))
plt.scatter(x, y)
plt.plot(x, y_pred1, color='b')
plt.xlabel('Level')
plt.ylabel('Salary')
plt.show()

# %%
print('RMSE for Linear Regression =>', round(np.sqrt(mean_squared_error(y, y_pred1)), 2))
# Out:
# RMSE for Linear Regression => 163388.74

# %% [markdown]
# Таким чином, модель поміноміальної регресії є більш точною у порівнянні з лінійною моделлю, що підтверджується розрахованими показниками RMSE і досить наглядно прослідковується візуально на побудованих графіках.
